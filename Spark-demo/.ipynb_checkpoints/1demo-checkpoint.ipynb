# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("MAgicTest").getOrCreate()
# Out:
# 26/06/12 16:46:59 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
data = [
       ("Magic",1),
       ("Docker",2),
       ("Spark",3)
]

df = spark.createDataFrame(data, ["name","ID"])

# %%
df.show()
# Out:
# +------+---+
# |  name| ID|
# +------+---+
# | Magic|  1|
# |Docker|  2|
# | Spark|  3|
# +------+---+
