# %%
from kafka import KafkaProducer
import json
import time
import random
producer = KafkaProducer(
    bootstrap_servers=['kafka:9092'],
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
    )
user_ids = [101, 102, 103, 104, 105]
print("Starting Transaction Producer...")
for i in range(100):
    tx_data = {
    "tx_id": i,
    "userId": random.choice(user_ids),
    "amount": random.uniform(10.0, 15000.0), # >10000 triggers fraud
    "timestamp": time.time()
    }
    producer.send('fraud-detection', value=tx_data)
    print(f"Sent: {tx_data}")
    time.sleep(2)
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 101, 'amount': 7151.151185581828, 'timestamp': 1781927657.4812787}
# Sent: {'tx_id': 1, 'userId': 104, 'amount': 11768.757044551136, 'timestamp': 1781927659.6083088}
# Sent: {'tx_id': 2, 'userId': 103, 'amount': 3450.9337169777623, 'timestamp': 1781927661.6088755}
# Sent: {'tx_id': 3, 'userId': 104, 'amount': 3958.1721561345776, 'timestamp': 1781927663.6097157}
# Sent: {'tx_id': 4, 'userId': 101, 'amount': 2621.48314028626, 'timestamp': 1781927665.6102045}
# Sent: {'tx_id': 5, 'userId': 105, 'amount': 1180.6899247126696, 'timestamp': 1781927667.61072}
# Sent: {'tx_id': 6, 'userId': 101, 'amount': 3238.385701428531, 'timestamp': 1781927669.6112375}
# Sent: {'tx_id': 7, 'userId': 104, 'amount': 8458.864851897015, 'timestamp': 1781927671.612401}
# Sent: {'tx_id': 8, 'userId': 101, 'amount': 7118.586243563034, 'timestamp': 1781927673.6130896}
# Sent: {'tx_id': 9, 'userId': 103, 'amount': 5903.823833007341, 'timestamp': 1781927675.61358}
# Sent: {'tx_id': 10, 'userId': 102, 'amount': 11641.017258862046, 'timestamp': 1781927677.6140506}
# Sent: {'tx_id': 11, 'userId': 104, 'amount': 10653.359411867055, 'timestamp': 1781927679.6154861}
# Sent: {'tx_id': 12, 'userId': 102, 'amount': 11902.23430308953, 'timestamp': 1781927681.6160927}
# Sent: {'tx_id': 13, 'userId': 103, 'amount': 4787.349424905569, 'timestamp': 1781927683.618293}
# Sent: {'tx_id': 14, 'userId': 101, 'amount': 6985.1322616546095, 'timestamp': 1781927685.6198642}
# Sent: {'tx_id': 15, 'userId': 104, 'amount': 6568.025624324796, 'timestamp': 1781927687.6212416}
# Sent: {'tx_id': 16, 'userId': 101, 'amount': 4164.802390889903, 'timestamp': 1781927689.6217892}
# Sent: {'tx_id': 17, 'userId': 105, 'amount': 6649.9573069185035, 'timestamp': 1781927691.6221988}
# Sent: {'tx_id': 18, 'userId': 104, 'amount': 538.5597984486943, 'timestamp': 1781927693.6226363}
# Sent: {'tx_id': 19, 'userId': 104, 'amount': 1492.6353874916663, 'timestamp': 1781927695.6237547}
# Sent: {'tx_id': 20, 'userId': 104, 'amount': 7048.915056441382, 'timestamp': 1781927697.6252966}
# Sent: {'tx_id': 21, 'userId': 101, 'amount': 3260.369378117204, 'timestamp': 1781927699.6266923}
# Sent: {'tx_id': 22, 'userId': 101, 'amount': 9608.233085080086, 'timestamp': 1781927701.627973}
# Sent: {'tx_id': 23, 'userId': 102, 'amount': 14150.632759162227, 'timestamp': 1781927703.6284347}
# Sent: {'tx_id': 24, 'userId': 103, 'amount': 9671.848303992956, 'timestamp': 1781927705.629499}
# Sent: {'tx_id': 25, 'userId': 101, 'amount': 12481.330009450803, 'timestamp': 1781927707.6307278}
# Sent: {'tx_id': 26, 'userId': 105, 'amount': 1355.4573803827293, 'timestamp': 1781927709.6313107}
# Sent: {'tx_id': 27, 'userId': 103, 'amount': 2410.1703948022646, 'timestamp': 1781927711.6337066}
# Sent: {'tx_id': 28, 'userId': 102, 'amount': 14702.258820402429, 'timestamp': 1781927713.635115}
# Sent: {'tx_id': 29, 'userId': 102, 'amount': 13588.921605840187, 'timestamp': 1781927715.6363835}
# Sent: {'tx_id': 30, 'userId': 104, 'amount': 5296.637376753893, 'timestamp': 1781927717.6368628}
# Sent: {'tx_id': 31, 'userId': 101, 'amount': 735.4814592625169, 'timestamp': 1781927719.63812}
# Sent: {'tx_id': 32, 'userId': 105, 'amount': 6547.329608365838, 'timestamp': 1781927721.6385918}
# Sent: {'tx_id': 33, 'userId': 101, 'amount': 10754.41289612063, 'timestamp': 1781927723.6391406}
# Sent: {'tx_id': 34, 'userId': 101, 'amount': 6829.4699311566665, 'timestamp': 1781927725.6396365}
# Sent: {'tx_id': 35, 'userId': 101, 'amount': 8716.471552593444, 'timestamp': 1781927727.6402297}
# Sent: {'tx_id': 36, 'userId': 105, 'amount': 8981.05062661804, 'timestamp': 1781927729.6406832}
# Sent: {'tx_id': 37, 'userId': 105, 'amount': 187.03856708187223, 'timestamp': 1781927731.6411614}
# Sent: {'tx_id': 38, 'userId': 102, 'amount': 10906.577313674474, 'timestamp': 1781927733.6416306}
# Sent: {'tx_id': 39, 'userId': 103, 'amount': 13841.4946007936, 'timestamp': 1781927735.642078}
# Sent: {'tx_id': 40, 'userId': 103, 'amount': 650.4760103854059, 'timestamp': 1781927737.642587}
# Sent: {'tx_id': 41, 'userId': 101, 'amount': 1795.7796578286031, 'timestamp': 1781927739.643816}
# Sent: {'tx_id': 42, 'userId': 101, 'amount': 5727.868434492372, 'timestamp': 1781927741.644932}
# Sent: {'tx_id': 43, 'userId': 105, 'amount': 13150.79262301435, 'timestamp': 1781927743.6460423}
# Sent: {'tx_id': 44, 'userId': 102, 'amount': 12720.49552477659, 'timestamp': 1781927745.647531}
# Sent: {'tx_id': 45, 'userId': 102, 'amount': 9566.825541726139, 'timestamp': 1781927747.6496122}
# Sent: {'tx_id': 46, 'userId': 105, 'amount': 2934.808946895885, 'timestamp': 1781927749.650223}
# Sent: {'tx_id': 47, 'userId': 103, 'amount': 7341.365815700219, 'timestamp': 1781927751.651651}
# Sent: {'tx_id': 48, 'userId': 105, 'amount': 14955.26817480427, 'timestamp': 1781927753.6521556}
# Sent: {'tx_id': 49, 'userId': 105, 'amount': 12408.224914538363, 'timestamp': 1781927755.652652}
# Sent: {'tx_id': 50, 'userId': 101, 'amount': 10363.878212405487, 'timestamp': 1781927757.6532567}
# Sent: {'tx_id': 51, 'userId': 102, 'amount': 11797.757138875919, 'timestamp': 1781927759.653939}
# Sent: {'tx_id': 52, 'userId': 101, 'amount': 12676.694679253416, 'timestamp': 1781927761.654573}
# Sent: {'tx_id': 53, 'userId': 104, 'amount': 2326.351032376953, 'timestamp': 1781927763.6550357}
# Sent: {'tx_id': 54, 'userId': 103, 'amount': 4266.653639517269, 'timestamp': 1781927765.6554763}
# Sent: {'tx_id': 55, 'userId': 105, 'amount': 11432.068159065462, 'timestamp': 1781927767.6565194}
# Sent: {'tx_id': 56, 'userId': 103, 'amount': 4051.494277097222, 'timestamp': 1781927769.65711}
# Sent: {'tx_id': 57, 'userId': 101, 'amount': 7835.007956545583, 'timestamp': 1781927771.658144}
# Sent: {'tx_id': 58, 'userId': 102, 'amount': 13416.530863065382, 'timestamp': 1781927773.6601944}
# Sent: {'tx_id': 59, 'userId': 102, 'amount': 14844.18411977576, 'timestamp': 1781927775.660669}
# Sent: {'tx_id': 60, 'userId': 103, 'amount': 14349.532827218174, 'timestamp': 1781927777.6618629}
# Sent: {'tx_id': 61, 'userId': 104, 'amount': 12268.413639114, 'timestamp': 1781927779.6625428}
# Sent: {'tx_id': 62, 'userId': 103, 'amount': 8850.083298364822, 'timestamp': 1781927781.6637845}
# Sent: {'tx_id': 63, 'userId': 101, 'amount': 549.4810710348378, 'timestamp': 1781927783.6649592}
# Sent: {'tx_id': 64, 'userId': 104, 'amount': 13428.349526353957, 'timestamp': 1781927785.6664588}
# Sent: {'tx_id': 65, 'userId': 105, 'amount': 14674.254635588552, 'timestamp': 1781927787.6670516}
# Sent: {'tx_id': 66, 'userId': 102, 'amount': 3209.9897576355315, 'timestamp': 1781927789.6678574}
# Sent: {'tx_id': 67, 'userId': 105, 'amount': 10057.221146885002, 'timestamp': 1781927791.6705382}
# Sent: {'tx_id': 68, 'userId': 103, 'amount': 14965.756321701527, 'timestamp': 1781927793.6725628}
# Sent: {'tx_id': 69, 'userId': 101, 'amount': 2140.084668868468, 'timestamp': 1781927795.6729946}
# Sent: {'tx_id': 70, 'userId': 103, 'amount': 8248.266340001848, 'timestamp': 1781927797.673532}
# Sent: {'tx_id': 71, 'userId': 104, 'amount': 3460.1313259359717, 'timestamp': 1781927799.674654}
# Sent: {'tx_id': 72, 'userId': 105, 'amount': 14626.428435771231, 'timestamp': 1781927801.6751335}
# Sent: {'tx_id': 73, 'userId': 101, 'amount': 6346.547189301476, 'timestamp': 1781927803.6765916}
# Sent: {'tx_id': 74, 'userId': 105, 'amount': 5322.95793330229, 'timestamp': 1781927805.6778882}
# Sent: {'tx_id': 75, 'userId': 105, 'amount': 13774.47344117679, 'timestamp': 1781927807.679102}
# Sent: {'tx_id': 76, 'userId': 104, 'amount': 4933.686621227118, 'timestamp': 1781927809.679556}
# Sent: {'tx_id': 77, 'userId': 104, 'amount': 3304.325052239167, 'timestamp': 1781927811.6815948}
# Sent: {'tx_id': 78, 'userId': 104, 'amount': 1223.3078876568895, 'timestamp': 1781927813.6837745}
# Sent: {'tx_id': 79, 'userId': 104, 'amount': 5092.888824557161, 'timestamp': 1781927815.6850216}
# Sent: {'tx_id': 80, 'userId': 102, 'amount': 13282.174690301763, 'timestamp': 1781927817.686386}
# Sent: {'tx_id': 81, 'userId': 104, 'amount': 2911.8748059349914, 'timestamp': 1781927819.687753}
# Sent: {'tx_id': 82, 'userId': 104, 'amount': 12979.446616931002, 'timestamp': 1781927821.6883793}
# Sent: {'tx_id': 83, 'userId': 101, 'amount': 3665.1276612507427, 'timestamp': 1781927823.689421}
# Sent: {'tx_id': 84, 'userId': 103, 'amount': 5376.256659198467, 'timestamp': 1781927825.691402}
# Sent: {'tx_id': 85, 'userId': 103, 'amount': 7020.961814620226, 'timestamp': 1781927827.692098}
# Sent: {'tx_id': 86, 'userId': 102, 'amount': 10263.315885002281, 'timestamp': 1781927829.6934588}
# Sent: {'tx_id': 87, 'userId': 105, 'amount': 5882.829383830878, 'timestamp': 1781927831.6939223}
# Sent: {'tx_id': 88, 'userId': 101, 'amount': 10458.57681703089, 'timestamp': 1781927833.6943796}
# Sent: {'tx_id': 89, 'userId': 101, 'amount': 8524.638114798216, 'timestamp': 1781927835.6947997}
# Sent: {'tx_id': 90, 'userId': 101, 'amount': 2588.5109698000565, 'timestamp': 1781927837.6960607}
# Sent: {'tx_id': 91, 'userId': 105, 'amount': 13723.79648357231, 'timestamp': 1781927839.6965036}
# Sent: {'tx_id': 92, 'userId': 101, 'amount': 13676.655381639346, 'timestamp': 1781927841.6976056}
# Sent: {'tx_id': 93, 'userId': 105, 'amount': 5104.206657607196, 'timestamp': 1781927843.6989963}
# Sent: {'tx_id': 94, 'userId': 101, 'amount': 9747.560493283647, 'timestamp': 1781927845.6995537}
# Sent: {'tx_id': 95, 'userId': 103, 'amount': 3659.4827270378173, 'timestamp': 1781927847.700265}
# Sent: {'tx_id': 96, 'userId': 104, 'amount': 1510.4544126498258, 'timestamp': 1781927849.701733}
# Sent: {'tx_id': 97, 'userId': 104, 'amount': 7508.287396081939, 'timestamp': 1781927851.7029374}
# Sent: {'tx_id': 98, 'userId': 104, 'amount': 8802.908674981752, 'timestamp': 1781927853.7041416}
# Sent: {'tx_id': 99, 'userId': 104, 'amount': 2537.6216943926393, 'timestamp': 1781927855.7058349}
